# %% [markdown]
# # Python Objeleri ve Veri Yapıları - 1
#
# + Değişkenler
# + Tip Dönüşümleri
# + Matematiksel Operatörler
# + Strings

# %%
print("Merhaba Dünya!")
# Out:
# Merhaba Dünya!

# %% [markdown]
# ## Değişkenler

# %%
name    = "Ömer Faruk" #string
surname = "Aydın"      #string
age     = 26           #int
pi      = 3.14         #float

# %%
print(name) #isim değişkeni ekrana yazdır
# Out:
# Ömer Faruk

# %%
type(pi)  #pi değişkenin tipini söyle
# Out:
# float

# %% [markdown]
# ## Tip Dönüşümleri

# %%
str(age)
# Out:
# '26'

# %%
print(type(age))
print(type(str(age)))
# Out:
# <class 'int'>
# <class 'str'>

# %%
int(pi)
# Out:
# 3

# %%
float(age)
# Out:
# 26.0

# %% [markdown]
# ## Matematiksel Operatörler

# %% [markdown]
# |İşlem|Operatör|
# |-----|-----|
# |toplama| + |
# |çıkarma| - |
# |çarpma| * |
# |bölme| / |
# |üs alma| ** |
# |mod alma| % |
# |kalansız bölme| // |

# %%
a = 5
b = 3

# %%
a + b
# Out:
# 8

# %%
a - b
# Out:
# 2

# %%
c = a * b

# %%
c
# Out:
# 15

# %%
a / b
# Out:
# 1.6666666666666667

# %%
a % b
# Out:
# 2

# %%
a // b
# Out:
# 1

# %%
a ** b
# Out:
# 125

# %%
pow(7,4)
# Out:
# 2401

# %% [markdown]
# ## Strings

# %%
metin = "Benim adım " + name + " soyadım " + surname

# %%
print(metin)
# Out:
# Benim adım Ömer Faruk soyadım Aydın

# %% [markdown]
# ### format() metodu

# %%
print("Benim adım {0} soyadım {1}. {2} Yaşındayım.".format(name,surname,age))
# Out:
# Benim adım Ömer Faruk soyadım Aydın. 26 Yaşındayım.

# %%
print(f"Merhaba {name} {surname}.")
# Out:
# Merhaba Ömer Faruk Aydın.

# %% [markdown]
# ### Kaçış dizesi

# %% [markdown]
# \n yeni satır
# \t bir tab boşluk
# \ kendisinden sonra geleni işlevsiz bırakır

# %%
print("Bugün IEEE ile Python öğreniyoruz.\nDersi anlatan: oemerfaruk\nÜniversite: YTÜ")
# Out:
# Bugün IEEE ile Python öğreniyoruz.
# Dersi anlatan: oemerfaruk
# Üniversite: YTÜ

# %% [markdown]
# ### Çoklu dize

# %%
print("""
YTÜ'de okuyorum
IEEE Üyesiyim
Sadece Derse Girerek Mühendis Olunmaz
""")
# Out:
# YTÜ'de okuyorum
# IEEE Üyesiyim
# Sadece Derse Girerek Mühendis Olunmaz

# %% [markdown]
# ### Metotlar

# %%
mesaj = "merhaba dünya"

# %%
print(mesaj)
# Out:
# merhaba dünya

# %%
mesaj.split() #split metotu varsayılan olarak 'boşluk' olduğu yerden ayırır.
# Out:
# ['merhaba', 'dünya']

# %%
mesaj.upper()
# Out:
# 'MERHABA DÜNYA'

# %%
mesaj.lower()
# Out:
# 'merhaba dünya'

# %%
mesaj.find("dünya")
# Out:
# 8

# %%
mesaj = "          merhaba dünya         "

# %%
mesaj
# Out:
# '          merhaba dünya         '

# %%
mesaj.strip()
# Out:
# 'merhaba dünya'

# %%
mesaj.replace("dünya","mars")
# Out:
# '          merhaba mars         '
