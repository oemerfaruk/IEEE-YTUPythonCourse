# %%
dosya = open("IEEE.txt", "w")

# %% [markdown]
# w: yazma
#
# doğrudan dosyanın üzerine yazar bundan dolayı dosyanın önceki içeriği yok olur
#
# r: okuma
#
# a: yazma

# %% [markdown]
# ## Dosya Yazma

# %%
dosya = open("IEEE.txt", "w")

# %%
dosya.write("IEEE Python Dersi")
# Out:
# 17

# %% [markdown]
# ## Dosya Kapatma

# %%
dosya.close()

# %% [markdown]
# ## Dosya Okuma

# %%
dosya = open("IEEE.txt", "r")

# %%
dosya
# Out:
# <_io.TextIOWrapper name='IEEE.txt' mode='r' encoding='utf-8'>

# %%
text = dosya.read()

print(text)
# Out:
# IEEE Python Dersi

# %%
dosya = open("IEEE.txt")
for each in dosya:
  print(each)
# Out:
# IEEE Python Dersi

# %%
dosya = open("IEEE.txt")
print(dosya.read(5))
# Out:
# IEEE

# %%
dosya.close()

# %% [markdown]
# ## readline()

# %%
dosya = open("IEEE.txt")
print(dosya.readline())
# Out:
# IEEE Python Dersi

# %%
print(dosya.readline())
# Out:
# ikinci satır

# %%
print(dosya.readline())
# Out:
# Sadece Derse Girerek Mühendiz Olunmaz

# %%
print(dosya.readline())
# Out:
# son satırs

# %%
print(dosya.readline())

# %% [markdown]
# ## readlines()

# %%
dosya = open("IEEE.txt")

# %%
print(dosya.readlines())
# Out:
# ['IEEE Python Dersi\n', 'ikinci satır\n', 'Sadece Derse Girerek Mühendis Olunmaz\n', 'son satır\n']

# %%
dosya.close()

# %% [markdown]
# ## with

# %%
with open("IEEE.txt", "r") as file:
  lines = file.readlines()

  for line in lines:
    # print(line)
    words = line.split()
    for word in words:
        print(word)
# Out:
# IEEE
# Python
# Dersi
# ikinci
# satır
# Sadece
# Derse
# Girerek
# Mühendis
# Olunmaz
# son
# satır

# %% [markdown]
# # uygulama

# %%
import random

# %%
iter = 0

while(iter < 10):
  val1 = random.randint(0,10)
  val2 = random.randint(0,100)

  with open("sistem.log", "a") as file:
    file.write(f"{iter}. satır\tval1: {val1} \t val2: {val2}\n")

  iter += 1
